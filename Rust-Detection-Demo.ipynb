# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import boto3
import sagemaker
from sagemaker.session import Session
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
region = 'us-east-1'
boto_session = boto3.Session(region_name=region)
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session()
region = sagemaker_session.boto_region_name
default_bucket = sagemaker_session.default_bucket()
prefix = 'sagemaker-featurestore'
offline_feature_store_bucket = 's3://*{}*/*{}*'.format(default_bucket, prefix)

sagemaker_client = boto_session.client(service_name='sagemaker', region_name=region)
featurestore_runtime = boto_session.client(service_name='sagemaker-featurestore-runtime', region_name=region)

feature_store_session = Session(
    boto_session=boto_session,
    sagemaker_client=sagemaker_client,
    sagemaker_featurestore_runtime_client=featurestore_runtime
)

# %%
TARGET_VAR = 'class'
FILE_TRAIN = 'train.csv'
FILE_VALIDATION = 'validation.csv'

# %%
def write_to_s3(fobj, bucket, key):
    return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(fobj)

def upload_to_s3(bucket, channel, filename):
    fobj=open(filename, 'rb')
    key = prefix+'/'+channel+'/'+filename
    url = 's3://{}/{}'.format(bucket, key)
    print('Writing to {}'.format(url))
    write_to_s3(fobj, bucket, key)     
    return(url)

# %%
# upload the files to the S3 bucket
s3_train_loc = upload_to_s3(bucket = 'rust-detection', channel = 'train', filename = FILE_TRAIN)
s3_valid_loc = upload_to_s3(bucket = 'rust-detection', channel = 'validation', filename = FILE_VALIDATION)
# Out:
# Writing to s3://rust-detection/sagemaker-featurestore/train/train.csv
# Writing to s3://rust-detection/sagemaker-featurestore/validation/validation.csv

# %%
xgboost_estimator = sagemaker.estimator.Estimator(
    '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',  # Docker container image URI
    role=get_execution_role(),  # IAM role for SageMaker
    instance_count=1,  # Number of instances for training
    instance_type='ml.c5.2xlarge',  # Type of EC2 instance for training
    output_path='s3://rust-output/my-training-output/output',  # S3 location for model artifacts
    sagemaker_session=sagemaker.Session()  # SageMaker session
)

# Set hyperparameters for XGBoost
xgboost_estimator.set_hyperparameters(
    max_depth=3,  # Maximum depth of the tree
    eta=0.2,  # Learning rate
    gamma=8,  # Minimum loss reduction required to make a further partition on a leaf node of the tree
    colsample_bytree=0.9,  # Fraction of features that are randomly chosen to grow trees
    subsample=0.8,  # Fraction of samples used for training
    num_round=100,  # Number of boosting rounds
    min_child_weight=10,  # Minimum sum of instance weight (hessian) needed in a child
    objective='multi:softmax',  # Objective function for multi-class classification
    num_class=2  # Number of classes for multi-class classification
)
s3_train_loc = 's3://rust-detection/sagemaker-featurestore/train/train.csv'
s3_valid_loc = 's3://rust-detection/sagemaker-featurestore/validation/validation.csv'

# Set the input data formatting and locations
s3_input_train = TrainingInput(s3_data=s3_train_loc, content_type='csv')
s3_input_validation = TrainingInput(s3_data=s3_valid_loc, content_type='csv')

# Train the XGBoost model
xgboost_estimator.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# WARNING:sagemaker.interactive_apps.base_interactive_app:NOTEBOOK_METADATA_FILE detected but failed to get valid domain and user from it.
# INFO:sagemaker:Creating training-job with name: xgboost-2023-09-18-19-03-18-471
# 2023-09-18 19:03:18 Starting - Starting the training job...
# 2023-09-18 19:03:43 Starting - Preparing the instances for training......
# 2023-09-18 19:04:39 Downloading - Downloading input data...
# 2023-09-18 19:05:14 Training - Downloading the training image...
# 2023-09-18 19:05:45 Uploading - Uploading generated training modelArguments: train
# [2023-09-18:19:05:32:INFO] Running standalone xgboost training.
# [2023-09-18:19:05:32:INFO] File size need to be processed in the node: 4.45mb. Available memory size in the node: 7990.82mb
# [2023-09-18:19:05:32:INFO] Determined delimiter of CSV input is ','
# [19:05:32] S3DistributionType set as FullyReplicated
# [19:05:32] 283462x3 matrix with 850386 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [51]#011train-merror:0.134462#011validation-merror:0.133929
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [52]#011train-merror:0.134113#011validation-merror:0.133221
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [53]#011train-merror:0.133969#011validation-merror:0.133024
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [54]#011train-merror:0.133923#011validation-merror:0.132925
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [55]#011train-merror:0.134029#011validation-merror:0.13281
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [56]#011train-merror:0.133771#011validation-merror:0.132464
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [57]#011train-merror:0.133595#011validation-merror:0.132316
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [58]#011train-merror:0.132522#011validation-merror:0.131229
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [59]#011train-merror:0.132198#011validation-merror:0.130949
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [60]#011train-merror:0.132194#011validation-merror:0.130982
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [61]#011train-merror:0.131937#011validation-merror:0.130637
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [62]#011train-merror:0.131541#011validation-merror:0.130357
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [63]#011train-merror:0.131527#011validation-merror:0.130505
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [64]#011train-merror:0.130568#011validation-merror:0.129616
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [65]#011train-merror:0.130536#011validation-merror:0.129665
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [66]#011train-merror:0.130144#011validation-merror:0.129435
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [67]#011train-merror:0.129816#011validation-merror:0.12927
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [68]#011train-merror:0.129965#011validation-merror:0.129435
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [69]#011train-merror:0.129718#011validation-merror:0.128974
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [70]#011train-merror:0.129989#011validation-merror:0.129303
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [71]#011train-merror:0.129185#011validation-merror:0.128447
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [72]#011train-merror:0.129739#011validation-merror:0.129122
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [73]#011train-merror:0.128433#011validation-merror:0.127904
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [74]#011train-merror:0.128356#011validation-merror:0.128003
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [75]#011train-merror:0.127883#011validation-merror:0.127278
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [76]#011train-merror:0.127573#011validation-merror:0.127113
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [77]#011train-merror:0.127167#011validation-merror:0.126587
# [19:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [78]#011train-merror:0.127058#011validation-merror:0.126406
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [79]#011train-merror:0.12729#011validation-merror:0.126438
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [80]#011train-merror:0.127354#011validation-merror:0.126257
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [81]#011train-merror:0.126927#011validation-merror:0.12578
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [82]#011train-merror:0.126797#011validation-merror:0.125879
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [83]#011train-merror:0.126133#011validation-merror:0.125368
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [84]#011train-merror:0.125664#011validation-merror:0.12499
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [85]#011train-merror:0.125519#011validation-merror:0.12494
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [86]#011train-merror:0.125558#011validation-merror:0.124924
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [87]#011train-merror:0.125262#011validation-merror:0.124693
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [88]#011train-merror:0.125297#011validation-merror:0.124776
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [89]#011train-merror:0.12522#011validation-merror:0.124825
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [90]#011train-merror:0.124775#011validation-merror:0.124446
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [91]#011train-merror:0.1245#011validation-merror:0.124084
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [92]#011train-merror:0.124345#011validation-merror:0.124018
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [93]#011train-merror:0.124376#011validation-merror:0.12364
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [94]#011train-merror:0.124246#011validation-merror:0.12387
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [95]#011train-merror:0.123851#011validation-merror:0.123656
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [96]#011train-merror:0.124073#011validation-merror:0.123689
# [19:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [97]#011train-merror:0.124193#011validation-merror:0.123936
# [19:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [19:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [98]#011train-merror:0.123752#011validation-merror:0.123327
# [19:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=3
# [19:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [99]#011train-merror:0.123417#011validation-merror:0.123047
#
# 2023-09-18 19:05:56 Completed - Training job completed
# Training seconds: 78
# Billable seconds: 78

# %%
xgboost_predictor = xgboost_estimator.deploy(initial_instance_count =2, instance_type = 'ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2023-09-18-19-27-51-893
# INFO:sagemaker:Creating endpoint-config with name xgboost-2023-09-18-19-27-51-893
# INFO:sagemaker:Creating endpoint with name xgboost-2023-09-18-19-27-51-893
# ---------!
